# %% [markdown]
# # WeatherPy

# %% [markdown]
# ## Generate Cities List

# %% [markdown]
# Latitude values range from -90 to 90
# Longitude values range from -180 to 180

# %%
# import dependencies
from citipy import citipy as cp
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from config import api_key
import requests
from datetime import date

# %%
# initialize list to store cities
cities = []

# set number of samples (cities) to be collected
sample_size = 1500

# randomly generate long & lat values
latitudes = np.random.uniform(low=-90, high=90.00000001, size=(sample_size,))
longitudes = np.random.uniform(low=-180, high=180.00000001, size=(sample_size,))

# %%
# generate cities list using citipy
for x in range(sample_size):
    city_name = cp.nearest_city(latitudes[x],longitudes[x]).city_name + ", " + cp.nearest_city(latitudes[x],longitudes[x]).country_code
    
    # only add city name to list if it is unique
    if (city_name not in cities):
        cities.append(city_name)

# print number of cities in the final list
print(len(cities))
# Out:
# 628

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# save config information
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# build partial query URL
url = f"{base_url}appid={api_key}&units={units}&q="

# %%
# initialize lists to store response variables
real_lat = []
real_lng = []
temp = []
humidity = []
cloudiness = []
wind_speed = []
final_city = []
country_code = []
date = []

date_of_execution = date.today().strftime("%m/%d/%y")

print("Beginning Data Retrieval\n-------------------------")

for index, city in enumerate(cities):
    try:
        city_response = requests.get(url + city).json()
        real_lat.append(city_response["coord"]["lat"])
        real_lng.append(city_response["coord"]["lon"])
        temp.append(city_response["main"]["temp_max"])
        humidity.append(city_response["main"]["humidity"])
        cloudiness.append(city_response["clouds"]["all"])
        wind_speed.append(city_response["wind"]["speed"])
        date.append(city_response["dt"])
        final_city.append(city.split(",")[0])
        country_code.append(city.split(",")[1])
        print(f"Processing Record {index+1} | {city}")
    except (KeyError):
        print(f"City {index+1} not found. Skipping... | {city}")
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 | busselton, au
# Processing Record 2 | punta arenas, cl
# Processing Record 3 | mahebourg, mu
# Processing Record 4 | mackay, au
# Processing Record 5 | homer, us
# Processing Record 6 | tasiilaq, gl
# Processing Record 7 | lavumisa, sz
# Processing Record 8 | qasigiannguit, gl
# Processing Record 9 | eureka, us
# Processing Record 10 | male, mv
# Processing Record 11 | carbonia, it
# Processing Record 12 | orocue, co
# Processing Record 13 | longyearbyen, sj
# City 14 not found. Skipping... | faya, td
# Processing Record 15 | naze, jp
# Processing Record 16 | ekibastuz, kz
# Processing Record 17 | korla, cn
# Processing Record 18 | yerbogachen, ru
# Processing Record 19 | ugoofaaru, mv
# Processing Record 20 | georgetown, sh
# Processing Record 21 | gouyave, gd
# City 22 not found. Skipping... | illoqqortoormiut, gl
# Processing Record 23 | hilo, us
# Processing Record 24 | piacabucu, br
# Processing Record 25 | bredasdorp, za
# Processing Record 26 | vaini, to
# Processing Record 27 | kieta, pg
# Processing Record 28 | tura, ru
# Processing Record 29 | ewa beach, us
# Processing Record 30 | fortuna, us
# Processing Record 31 | nikolskoye, ru
# Processing Record 32 | rikitea, pf
# Processing Record 33 | aranos, na
# Processing Record 34 | lompoc, us
# Processing Record 35 | srednekolymsk, ru
# Processing Record 36 | pekalongan, id
# Processing Record 37 | comodoro rivadavia, ar
# Processing Record 38 | hay river, ca
# City 39 not found. Skipping... | grand river south east, mu
# Processing Record 40 | katsuura, jp
# Processing Record 41 | ahipara, nz
# Processing Record 42 | ushuaia, ar
# Processing Record 43 | charagua, bo
# Processing Record 44 | andenes, no
# Processing Record 45 | khatanga, ru
# Processing Record 46 | esperance, au
# Processing Record 47 | cape town, za
# Processing Record 48 | constitucion, mx
# Processing Record 49 | batagay, ru
# Processing Record 50 | tungor, ru
# City 51 not found. Skipping... | bababe, mr
# City 52 not found. Skipping... | vaitupu, wf
# Processing Record 53 | kharagpur, in
# Processing Record 54 | chuy, uy
# Processing Record 55 | husavik, is
# Processing Record 56 | petropavlovsk-kamchatskiy, ru
# Processing Record 57 | bluff, nz
# Processing Record 58 | tuktoyaktuk, ca
# Processing Record 59 | qaanaaq, gl
# Processing Record 60 | victoria, sc
# Processing Record 61 | chokurdakh, ru
# Processing Record 62 | kaitangata, nz
# Processing Record 63 | arraial do cabo, br
# City 64 not found. Skipping... | saleaula, ws
# Processing Record 65 | carnarvon, au
# Processing Record 66 | bethel, us
# Processing Record 67 | norman wells, ca
# Processing Record 68 | east london, za
# Processing Record 69 | belaya gora, ru
# Processing Record 70 | guerrero negro, mx
# City 71 not found. Skipping... | barentsburg, sj
# Processing Record 72 | san cristobal, ec
# Processing Record 73 | port lincoln, au
# Processing Record 74 | tilichiki, ru
# Processing Record 75 | rawson, ar
# Processing Record 76 | mvuma, zw
# Processing Record 77 | namibe, ao
# Processing Record 78 | atuona, pf
# Processing Record 79 | kidal, ml
# Processing Record 80 | oranjemund, na
# City 81 not found. Skipping... | tsihombe, mg
# Processing Record 82 | jamestown, sh
# Processing Record 83 | torbay, ca
# Processing Record 84 | port blair, in
# Processing Record 85 | mount gambier, au
# Processing Record 86 | hermanus, za
# City 87 not found. Skipping... | guanica, us
# Processing Record 88 | alofi, nu
# Processing Record 89 | port elizabeth, za
# Processing Record 90 | mana, gf
# Processing Record 91 | hobart, au
# Processing Record 92 | hambantota, lk
# Processing Record 93 | mar del plata, ar
# Processing Record 94 | okha, ru
# Processing Record 95 | brokopondo, sr
# Processing Record 96 | villa rica, pe
# Processing Record 97 | vestmannaeyjar, is
# Processing Record 98 | cayenne, gf
# City 99 not found. Skipping... | amderma, ru
# City 100 not found. Skipping... | belushya guba, ru
# Processing Record 101 | faanui, pf
# Processing Record 102 | port hawkesbury, ca
# Processing Record 103 | moyale, et
# Processing Record 104 | baft, ir
# Processing Record 105 | detchino, ru
# City 106 not found. Skipping... | saint anthony, ca
# Processing Record 107 | castro, cl
# Processing Record 108 | dikson, ru
# Processing Record 109 | fulton, us
# Processing Record 110 | ribeira grande, pt
# Processing Record 111 | luanda, ao
# Processing Record 112 | laguna, br
# Processing Record 113 | mariental, na
# Processing Record 114 | sao filipe, cv
# Processing Record 115 | provideniya, ru
# Processing Record 116 | nhulunbuy, au
# Processing Record 117 | talcher, in
# Processing Record 118 | kapaa, us
# Processing Record 119 | mattru, sl
# Processing Record 120 | severo-kurilsk, ru
# Processing Record 121 | fruitvale, ca
# City 122 not found. Skipping... | lolua, tv
# Processing Record 123 | yatou, cn
# Processing Record 124 | coquimbo, cl
# City 125 not found. Skipping... | mataura, pf
# Processing Record 126 | salym, ru
# Processing Record 127 | muzhi, ru
# Processing Record 128 | hasaki, jp
# Processing Record 129 | hamilton, bm
# Processing Record 130 | meulaboh, id
# Processing Record 131 | puerto baquerizo moreno, ec
# Processing Record 132 | axim, gh
# Processing Record 133 | ust-kulom, ru
# Processing Record 134 | gambiran, id
# City 135 not found. Skipping... | barbar, sd
# Processing Record 136 | saint-philippe, re
# Processing Record 137 | butaritari, ki
# Processing Record 138 | namatanai, pg
# City 139 not found. Skipping... | taolanaro, mg
# Processing Record 140 | pisco, pe
# City 141 not found. Skipping... | mys shmidta, ru
# Processing Record 142 | jiangyou, cn
# Processing Record 143 | denpasar, id
# Processing Record 144 | calatayud, es
# Processing Record 145 | aklavik, ca
# Processing Record 146 | vilhena, br
# Processing Record 147 | bengkulu, id
# Processing Record 148 | noumea, nc
# Processing Record 149 | bambous virieux, mu
# Processing Record 150 | nanortalik, gl
# Processing Record 151 | albany, au
# Processing Record 152 | mortka, ru
# Processing Record 153 | puerto ayora, ec
# Processing Record 154 | banda aceh, id
# Processing Record 155 | burnie, au
# City 156 not found. Skipping... | attawapiskat, ca
# Processing Record 157 | granville, fr
# Processing Record 158 | grua, no
# Processing Record 159 | finale ligure, it
# Processing Record 160 | thompson, ca
# Processing Record 161 | chimore, bo
# City 162 not found. Skipping... | gurskoye, ru
# Processing Record 163 | hualmay, pe
# Processing Record 164 | vardo, no
# City 165 not found. Skipping... | mahadday weyne, so
# Processing Record 166 | neya, ru
# Processing Record 167 | narsaq, gl
# Processing Record 168 | vuktyl, ru
# Processing Record 169 | bambanglipuro, id
# Processing Record 170 | rio gallegos, ar
# Processing Record 171 | ezequiel montes, mx
# Processing Record 172 | oromocto, ca
# Processing Record 173 | dourbali, td
# Processing Record 174 | rio grande, br
# Processing Record 175 | riviere-au-renard, ca
# Processing Record 176 | hastings, us
# Processing Record 177 | ust-kuyga, ru
# Processing Record 178 | kruisfontein, za
# Processing Record 179 | clyde river, ca
# Processing Record 180 | liverpool, ca
# City 181 not found. Skipping... | bocaranga, cf
# Processing Record 182 | san policarpo, ph
# Processing Record 183 | nuuk, gl
# Processing Record 184 | henties bay, na
# Processing Record 185 | inhambane, mz
# Processing Record 186 | taguatinga, br
# Processing Record 187 | sibu, my
# Processing Record 188 | ponta do sol, cv
# Processing Record 189 | zhoucheng, cn
# Processing Record 190 | lagoa, pt
# Processing Record 191 | garavuti, tj
# Processing Record 192 | prince albert, ca
# Processing Record 193 | saldanha, za
# Processing Record 194 | chapais, ca
# Processing Record 195 | san patricio, mx
# Processing Record 196 | jamestown, us
# Processing Record 197 | sakakah, sa
# Processing Record 198 | barrow, us
# Processing Record 199 | naantali, fi
# Processing Record 200 | leesburg, us
# Processing Record 201 | port alfred, za
# Processing Record 202 | sao joao da barra, br
# City 203 not found. Skipping... | marcona, pe
# Processing Record 204 | sidney, us
# Processing Record 205 | ixtapa, mx
# Processing Record 206 | gimli, ca
# Processing Record 207 | lorengau, pg
# Processing Record 208 | mount isa, au
# Processing Record 209 | soyo, ao
# Processing Record 210 | isla mujeres, mx
# Processing Record 211 | srandakan, id
# Processing Record 212 | mahajanga, mg
# Processing Record 213 | pareora, nz
# Processing Record 214 | salinopolis, br
# Processing Record 215 | benjamin hill, mx
# Processing Record 216 | parabel, ru
# Processing Record 217 | bilma, ne
# Processing Record 218 | new norfolk, au
# Processing Record 219 | kempsey, au
# Processing Record 220 | millington, us
# Processing Record 221 | hobyo, so
# Processing Record 222 | garowe, so
# Processing Record 223 | ostrovnoy, ru
# Processing Record 224 | cabo san lucas, mx
# Processing Record 225 | christchurch, nz
# Processing Record 226 | riyadh, sa
# Processing Record 227 | cap malheureux, mu
# Processing Record 228 | mendi, et
# City 229 not found. Skipping... | sovetskiy, tj
# Processing Record 230 | san luis, gt
# Processing Record 231 | valparaiso, cl
# Processing Record 232 | yellowknife, ca
# Processing Record 233 | hithadhoo, mv
# Processing Record 234 | avarua, ck
# Processing Record 235 | lebu, cl
# Processing Record 236 | cherskiy, ru
# Processing Record 237 | itarema, br
# Processing Record 238 | timiryazevskiy, ru
# Processing Record 239 | benjamin constant, br
# Processing Record 240 | mbaiki, cf
# Processing Record 241 | puerto cabello, ve
# Processing Record 242 | nishihara, jp
# Processing Record 243 | santa maria, cv
# Processing Record 244 | swan river, ca
# Processing Record 245 | yar-sale, ru
# Processing Record 246 | taybad, ir
# Processing Record 247 | omboue, ga
# Processing Record 248 | upernavik, gl
# Processing Record 249 | tessalit, ml
# Processing Record 250 | flin flon, ca
# Processing Record 251 | nha trang, vn
# Processing Record 252 | wau, pg
# City 253 not found. Skipping... | san carlos, py
# Processing Record 254 | beloha, mg
# Processing Record 255 | souillac, mu
# Processing Record 256 | reconquista, ar
# Processing Record 257 | rassvet, ru
# Processing Record 258 | banff, ca
# Processing Record 259 | gushikawa, jp
# Processing Record 260 | ossora, ru
# City 261 not found. Skipping... | paucartambo, pe
# Processing Record 262 | foam lake, ca
# Processing Record 263 | aban, ru
# Processing Record 264 | ambunti, pg
# Processing Record 265 | leshukonskoye, ru
# Processing Record 266 | sobolevo, ru
# Processing Record 267 | kanniyakumari, in
# Processing Record 268 | nabire, id
# City 269 not found. Skipping... | ambodifototra, mg
# Processing Record 270 | broome, au
# Processing Record 271 | marsa matruh, eg
# Processing Record 272 | williston, us
# Processing Record 273 | senador jose porfirio, br
# City 274 not found. Skipping... | tumannyy, ru
# Processing Record 275 | haines junction, ca
# Processing Record 276 | tamworth, au
# Processing Record 277 | chester, ca
# Processing Record 278 | byron bay, au
# Processing Record 279 | road town, vg
# Processing Record 280 | newport, us
# Processing Record 281 | thinadhoo, mv
# Processing Record 282 | tabuk, sa
# Processing Record 283 | saint-georges, gf
# Processing Record 284 | sungaipenuh, id
# Processing Record 285 | puerto del rosario, es
# Processing Record 286 | lamar, us
# Processing Record 287 | olafsvik, is
# Processing Record 288 | pevek, ru
# Processing Record 289 | makakilo city, us
# Processing Record 290 | the valley, ai
# Processing Record 291 | anloga, gh
# Processing Record 292 | eftimie murgu, ro
# Processing Record 293 | pedra branca, br
# City 294 not found. Skipping... | sorvag, fo
# Processing Record 295 | kodiak, us
# Processing Record 296 | misratah, ly
# Processing Record 297 | san vicente, ph
# City 298 not found. Skipping... | kuche, cn
# Processing Record 299 | isangel, vu
# City 300 not found. Skipping... | umzimvubu, za
# Processing Record 301 | kalmunai, lk
# Processing Record 302 | merauke, id
# Processing Record 303 | iqaluit, ca
# City 304 not found. Skipping... | kazalinsk, kz
# Processing Record 305 | progreso, mx
# Processing Record 306 | pochutla, mx
# Processing Record 307 | roebourne, au
# Processing Record 308 | olinda, br
# Processing Record 309 | bundaberg, au
# Processing Record 310 | tezu, in
# Processing Record 311 | alakurtti, ru
# Processing Record 312 | college, us
# Processing Record 313 | robertson, za
# City 314 not found. Skipping... | nizhneyansk, ru
# Processing Record 315 | kemijarvi, fi
# Processing Record 316 | tocopilla, cl
# Processing Record 317 | ouesso, cg
# Processing Record 318 | alamosa, us
# City 319 not found. Skipping... | asau, tv
# Processing Record 320 | westport, ie
# Processing Record 321 | deoband, in
# Processing Record 322 | salalah, om
# Processing Record 323 | show low, us
# Processing Record 324 | kahului, us
# Processing Record 325 | vakhtan, ru
# Processing Record 326 | yangambi, cd
# Processing Record 327 | ancud, cl
# Processing Record 328 | sompeta, in
# Processing Record 329 | trindade, br
# Processing Record 330 | along, in
# Processing Record 331 | teguise, es
# Processing Record 332 | aswan, eg
# City 333 not found. Skipping... | bolshegrivskoye, ru
# Processing Record 334 | radford, us
# Processing Record 335 | balkanabat, tm
# City 336 not found. Skipping... | wulanhaote, cn
# Processing Record 337 | samarai, pg
# Processing Record 338 | tiksi, ru
# City 339 not found. Skipping... | jarjis, tn
# Processing Record 340 | berezovyy, ru
# Processing Record 341 | tadine, nc
# Processing Record 342 | banes, cu
# Processing Record 343 | manakara, mg
# Processing Record 344 | gamba, ga
# City 345 not found. Skipping... | ruatoria, nz
# Processing Record 346 | parana, ar
# Processing Record 347 | luwuk, id
# City 348 not found. Skipping... | samusu, ws
# Processing Record 349 | opuwo, na
# Processing Record 350 | marion, us
# City 351 not found. Skipping... | airai, pw
# Processing Record 352 | alice springs, au
# Processing Record 353 | ayan, ru
# Processing Record 354 | necochea, ar
# Processing Record 355 | portland, au
# City 356 not found. Skipping... | eldikan, ru
# Processing Record 357 | itoman, jp
# City 358 not found. Skipping... | codrington, ag
# Processing Record 359 | tairua, nz
# Processing Record 360 | kimparana, ml
# Processing Record 361 | benguela, ao
# Processing Record 362 | umea, se
# Processing Record 363 | wajir, ke
# Processing Record 364 | ponta do sol, pt
# Processing Record 365 | valleyview, ca
# City 366 not found. Skipping... | grand centre, ca
# Processing Record 367 | usinsk, ru
# Processing Record 368 | labuhan, id
# Processing Record 369 | mitsamiouli, km
# Processing Record 370 | ukiah, us
# Processing Record 371 | komsomolskiy, ru
# Processing Record 372 | indi, in
# Processing Record 373 | nadym, ru
# Processing Record 374 | baiyin, cn
# Processing Record 375 | joshimath, in
# Processing Record 376 | berlevag, no
# Processing Record 377 | matara, lk
# Processing Record 378 | la macarena, co
# City 379 not found. Skipping... | mixtequilla, mx
# Processing Record 380 | caratinga, br
# Processing Record 381 | dar es salaam, tz
# Processing Record 382 | te anau, nz
# Processing Record 383 | smithers, ca
# Processing Record 384 | gioia tauro, it
# Processing Record 385 | grand gaube, mu
# City 386 not found. Skipping... | bargal, so
# Processing Record 387 | amapa, br
# Processing Record 388 | forst, de
# Processing Record 389 | sorong, id
# Processing Record 390 | xichang, cn
# City 391 not found. Skipping... | jiddah, sa
# Processing Record 392 | tumpat, my
# Processing Record 393 | falmouth, gb
# City 394 not found. Skipping... | ngukurr, au
# Processing Record 395 | ilulissat, gl
# City 396 not found. Skipping... | wampusirpi, hn
# Processing Record 397 | kismayo, so
# Processing Record 398 | gravdal, no
# Processing Record 399 | hirara, jp
# Processing Record 400 | talnakh, ru
# Processing Record 401 | kavieng, pg
# Processing Record 402 | loralai, pk
# Processing Record 403 | kang, bw
# Processing Record 404 | xingtai, cn
# Processing Record 405 | touros, br
# Processing Record 406 | sugar hill, us
# City 407 not found. Skipping... | kawana waters, au
# Processing Record 408 | bako, et
# Processing Record 409 | poum, nc
# Processing Record 410 | vanimo, pg
# Processing Record 411 | nanhai, cn
# Processing Record 412 | saint george, bm
# Processing Record 413 | saskylakh, ru
# Processing Record 414 | sitka, us
# City 415 not found. Skipping... | vila, vu
# City 416 not found. Skipping... | labutta, mm
# Processing Record 417 | marienburg, sr
# Processing Record 418 | lisakovsk, kz
# City 419 not found. Skipping... | holme, no
# City 420 not found. Skipping... | naftah, tn
# Processing Record 421 | muros, es
# Processing Record 422 | bonavista, ca
# Processing Record 423 | beyneu, kz
# Processing Record 424 | kyakhta, ru
# Processing Record 425 | awjilah, ly
# Processing Record 426 | leningradskiy, ru
# Processing Record 427 | tual, id
# Processing Record 428 | camacha, pt
# Processing Record 429 | farmington, us
# Processing Record 430 | san andres, co
# Processing Record 431 | mandalgovi, mn
# Processing Record 432 | koutsouras, gr
# Processing Record 433 | barcelos, br
# Processing Record 434 | shetpe, kz
# Processing Record 435 | takoradi, gh
# Processing Record 436 | abapo, bo
# Processing Record 437 | cabinda, ao
# Processing Record 438 | qixingtai, cn
# Processing Record 439 | pangnirtung, ca
# Processing Record 440 | luderitz, na
# Processing Record 441 | san pedro buenavista, mx
# Processing Record 442 | vao, nc
# Processing Record 443 | lai, td
# Processing Record 444 | hurghada, eg
# City 445 not found. Skipping... | cagayan de tawi-tawi, ph
# Processing Record 446 | klaksvik, fo
# Processing Record 447 | sao felix do xingu, br
# Processing Record 448 | colwyn bay, gb
# Processing Record 449 | concordia, hn
# Processing Record 450 | vallenar, cl
# Processing Record 451 | yulara, au
# Processing Record 452 | pacific grove, us
# Processing Record 453 | kaka, tm
# Processing Record 454 | jatai, br
# Processing Record 455 | acapulco, mx
# City 456 not found. Skipping... | bobonong, bw
# City 457 not found. Skipping... | formoso do araguaia, br
# Processing Record 458 | saint-pierre, pm
# City 459 not found. Skipping... | avera, pf
# Processing Record 460 | grand-lahou, ci
# Processing Record 461 | capreol, ca
# Processing Record 462 | acajutla, sv
# Processing Record 463 | praia da vitoria, pt
# Processing Record 464 | buala, sb
# Processing Record 465 | hervey bay, au
# Processing Record 466 | araouane, ml
# Processing Record 467 | nizhniy tsasuchey, ru
# Processing Record 468 | oksfjord, no
# Processing Record 469 | shelburne, ca
# Processing Record 470 | svetlyy, ru
# Processing Record 471 | adrar, dz
# Processing Record 472 | deputatskiy, ru
# Processing Record 473 | pyu, mm
# Processing Record 474 | kamenka, ru
# Processing Record 475 | okhotsk, ru
# Processing Record 476 | ishigaki, jp
# Processing Record 477 | cidreira, br
# Processing Record 478 | sioux lookout, ca
# Processing Record 479 | hebi, cn
# Processing Record 480 | novyy svit, ua
# Processing Record 481 | tazmalt, dz
# Processing Record 482 | kalianget, id
# Processing Record 483 | warwick, ca
# Processing Record 484 | atbasar, kz
# Processing Record 485 | tahe, cn
# Processing Record 486 | kisangani, cd
# City 487 not found. Skipping... | yomitan, jp
# Processing Record 488 | sambava, mg
# Processing Record 489 | jasper, ca
# Processing Record 490 | talakan, ru
# Processing Record 491 | barra do garcas, br
# City 492 not found. Skipping... | borlange, se
# Processing Record 493 | yokadouma, cm
# Processing Record 494 | otavi, na
# Processing Record 495 | zahir pir, pk
# Processing Record 496 | ketchikan, us
# Processing Record 497 | la ronge, ca
# Processing Record 498 | mokhsogollokh, ru
# Processing Record 499 | san juan del sur, ni
# Processing Record 500 | skegness, gb
# Processing Record 501 | bangolo, ci
# Processing Record 502 | hereford, us
# Processing Record 503 | nalbari, in
# Processing Record 504 | boundiali, ci
# Processing Record 505 | imbituba, br
# Processing Record 506 | russell, nz
# Processing Record 507 | vila velha, br
# Processing Record 508 | arawa, pg
# Processing Record 509 | sainte-anne-des-monts, ca
# Processing Record 510 | taoudenni, ml
# Processing Record 511 | solnechnyy, ru
# City 512 not found. Skipping... | utiroa, ki
# Processing Record 513 | yurginskoye, ru
# Processing Record 514 | tobane, bw
# Processing Record 515 | port hardy, ca
# Processing Record 516 | muisne, ec
# Processing Record 517 | manado, id
# Processing Record 518 | zakamensk, ru
# Processing Record 519 | port augusta, au
# Processing Record 520 | salvador, br
# Processing Record 521 | taltal, cl
# Processing Record 522 | murgab, tm
# Processing Record 523 | nisia floresta, br
# Processing Record 524 | tromso, no
# Processing Record 525 | huancavelica, pe
# Processing Record 526 | tsubata, jp
# Processing Record 527 | aksha, ru
# Processing Record 528 | ozinki, ru
# Processing Record 529 | kajaani, fi
# City 530 not found. Skipping... | makung, tw
# Processing Record 531 | paamiut, gl
# Processing Record 532 | kizukuri, jp
# City 533 not found. Skipping... | sentyabrskiy, ru
# Processing Record 534 | seoul, kr
# Processing Record 535 | surgut, ru
# Processing Record 536 | camacari, br
# Processing Record 537 | manokwari, id
# Processing Record 538 | vengerovo, ru
# Processing Record 539 | mykolayiv, ua
# Processing Record 540 | tautira, pf
# Processing Record 541 | geraldton, au
# Processing Record 542 | bratsk, ru
# Processing Record 543 | dawlatabad, af
# Processing Record 544 | basoko, cd
# Processing Record 545 | socoltenango, mx
# Processing Record 546 | tynda, ru
# Processing Record 547 | conceicao do araguaia, br
# Processing Record 548 | mareeba, au
# Processing Record 549 | dubbo, au
# Processing Record 550 | tabou, ci
# City 551 not found. Skipping... | marzuq, ly
# Processing Record 552 | bin qirdan, tn
# Processing Record 553 | san quintin, mx
# Processing Record 554 | hurricane, us
# Processing Record 555 | lucapa, ao
# Processing Record 556 | yenagoa, ng
# Processing Record 557 | havelock, us
# City 558 not found. Skipping... | tubruq, ly
# Processing Record 559 | skerries, ie
# Processing Record 560 | culiacan, mx
# Processing Record 561 | halifax, ca
# Processing Record 562 | abadiania, br
# Processing Record 563 | nagato, jp
# Processing Record 564 | inta, ru
# Processing Record 565 | ryki, pl
# Processing Record 566 | xining, cn
# Processing Record 567 | dalmatovo, ru
# Processing Record 568 | girne, cy
# Processing Record 569 | baykit, ru
# Processing Record 570 | praia, cv
# Processing Record 571 | sibolga, id
# Processing Record 572 | nadaun, in
# Processing Record 573 | paoua, cf
# Processing Record 574 | banjar, id
# Processing Record 575 | eyl, so
# Processing Record 576 | dingle, ie
# Processing Record 577 | flinders, au
# Processing Record 578 | voh, nc
# Processing Record 579 | fukue, jp
# Processing Record 580 | bumba, cd
# Processing Record 581 | tigil, ru
# Processing Record 582 | vanavara, ru
# Processing Record 583 | ridgecrest, us
# Processing Record 584 | san jose, gt
# Processing Record 585 | sorland, no
# Processing Record 586 | kabompo, zm
# City 587 not found. Skipping... | aflu, dz
# Processing Record 588 | beaupre, ca
# Processing Record 589 | haifa, il
# Processing Record 590 | jacareacanga, br
# Processing Record 591 | rybnoye, ru
# Processing Record 592 | waipawa, nz
# Processing Record 593 | coahuayana, mx
# Processing Record 594 | kununurra, au
# Processing Record 595 | nome, us
# Processing Record 596 | anadyr, ru
# Processing Record 597 | sinnamary, gf
# Processing Record 598 | ballina, ie
# Processing Record 599 | altamira, br
# Processing Record 600 | barra patuca, hn
# Processing Record 601 | fairbanks, us
# Processing Record 602 | nyeri, ke
# Processing Record 603 | kurilsk, ru
# Processing Record 604 | thunder bay, ca
# Processing Record 605 | narathiwat, th
# Processing Record 606 | bartica, gy
# Processing Record 607 | krasnoselkup, ru
# Processing Record 608 | jumla, np
# Processing Record 609 | umm lajj, sa
# Processing Record 610 | itigi, tz
# Processing Record 611 | monte patria, cl
# Processing Record 612 | teofilo otoni, br
# City 613 not found. Skipping... | shchelyayur, ru
# Processing Record 614 | kwinana, au
# Processing Record 615 | belmonte, br
# Processing Record 616 | linfen, cn
# Processing Record 617 | bonthe, sl
# Processing Record 618 | hofn, is
# Processing Record 619 | foshan, cn
# Processing Record 620 | tougan, bf
# Processing Record 621 | viedma, ar
# Processing Record 622 | gladstone, au
# Processing Record 623 | izhma, ru
# Processing Record 624 | rawah, iq
# Processing Record 625 | jawhar, so
# Processing Record 626 | astoria, us
# City 627 not found. Skipping... | valea lunga, ro
# Processing Record 628 | plettenberg bay, za

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create dataframe with data generated from API calls
weather_df = pd.DataFrame({"City": final_city, 
                           "Lat": real_lat, 
                           "Lng": real_lng, 
                           "Max Temp": temp, 
                           "Humidity": humidity,
                           "Cloudiness": cloudiness,
                           "Wind Speed": wind_speed,
                           "Country": country_code,
                           "Date": date
                          })

# output dataframe to csv file
weather_df.to_csv("Output/weather_output.csv", index=False, header=True)

# %%
# display dataframe
weather_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          busselton -33.6500  115.3333     51.04        80          93
# 1       punta arenas -53.1500  -70.9167     35.71        93          75
# 2          mahebourg -20.4081   57.7000     70.09        83          75
# 3             mackay -21.1500  149.2000     60.04        87           0
# 4              homer  59.6425 -151.5483     55.08        90         100
# ..               ...      ...       ...       ...       ...         ...
# 557            izhma  65.0083   53.9113     63.70        62          88
# 558            rawah  34.4816   41.9093    107.33        12           0
# 559           jawhar   2.7809   45.5005     82.92        59          61
# 560          astoria  46.1879 -123.8313     57.85        94           1
# 561  plettenberg bay -34.0527   23.3716     51.98        78          64
#
#      Wind Speed Country        Date
# 0          8.55      au  1626875931
# 1          3.44      cl  1626875914
# 2         18.41      mu  1626875954
# 3          5.75      au  1626875954
# 4          1.99      us  1626875955
# ..          ...     ...         ...
# 557       11.21      ru  1626876868
# 558       16.40      iq  1626876869
# 559       23.47      so  1626876869
# 560        3.44      us  1626876870
# 561       29.19      za  1626876872
#
# [562 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# inspect the basic statistical values of the dataframe, paying attention to make sure no max humidity over 100
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  562.000000  562.000000  562.000000  562.000000  562.000000  562.000000
# mean    18.583831   17.570557   71.419644   68.151246   56.813167    8.514502
# std     33.648929   90.827241   15.184784   22.921479   39.204509    6.664924
# min    -54.800000 -175.200000   28.060000    5.000000    0.000000    0.000000
# 25%     -8.240850  -62.978575   60.690000   56.000000   15.000000    3.565000
# 50%     20.683350   19.962850   73.945000   74.000000   70.000000    6.590000
# 75%     49.122125  101.099975   81.100000   86.000000   97.000000   11.482500
# max     78.218600  178.416700  119.410000  100.000000  100.000000   51.290000
#
#                Date
# count  5.620000e+02
# mean   1.626877e+09
# std    2.310439e+02
# min    1.626876e+09
# 25%    1.626876e+09
# 50%    1.626877e+09
# 75%    1.626877e+09
# max    1.626877e+09

# %%
# get the indices of cities that have humidity over 100%
bad_data = []

if weather_df["Humidity"].max() > 100:
    bad_data = weather_df.loc[weather_df["Humidity"]>100, :].index.values
    print(bad_data)

# %%
# create new dataframe while dropping humidity outliers by index value
clean_weather_df = weather_df.drop(bad_data, inplace=False)
clean_weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  562.000000  562.000000  562.000000  562.000000  562.000000  562.000000
# mean    18.583831   17.570557   71.419644   68.151246   56.813167    8.514502
# std     33.648929   90.827241   15.184784   22.921479   39.204509    6.664924
# min    -54.800000 -175.200000   28.060000    5.000000    0.000000    0.000000
# 25%     -8.240850  -62.978575   60.690000   56.000000   15.000000    3.565000
# 50%     20.683350   19.962850   73.945000   74.000000   70.000000    6.590000
# 75%     49.122125  101.099975   81.100000   86.000000   97.000000   11.482500
# max     78.218600  178.416700  119.410000  100.000000  100.000000   51.290000
#
#                Date
# count  5.620000e+02
# mean   1.626877e+09
# std    2.310439e+02
# min    1.626876e+09
# 25%    1.626876e+09
# 50%    1.626877e+09
# 75%    1.626877e+09
# max    1.626877e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(clean_weather_df["Lat"],clean_weather_df["Max Temp"],color="teal", edgecolors="black")
plt.title("City Latitude vs Max Temperature (" + date_of_execution + ")")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Output/Lat_v_Temp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(clean_weather_df["Lat"],clean_weather_df["Humidity"],color="teal", edgecolors="black")
plt.title("City Latitude vs Humidity (" + date_of_execution + ")")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Output/Lat_v_Humid.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(clean_weather_df["Lat"],clean_weather_df["Cloudiness"],color="teal", edgecolors="black")
plt.title("City Latitude vs Cloudiness (" + date_of_execution + ")")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Output/Lat_v_Cloud.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(clean_weather_df["Lat"],clean_weather_df["Wind Speed"],color="teal", edgecolors="black")
plt.title("City Latitude vs Wind Speed (" + date_of_execution + ")")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
plt.savefig("Output/Lat_v_Wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
